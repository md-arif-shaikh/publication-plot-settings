# %%
import plotsettings as plts
import numpy as np

# %%
x = np.arange(-np.pi, np.pi, 0.01)

# %%
fig, ax = plts.set("PRD")
for idx in range(10):
    ax.plot(x, np.sin(x + idx))
ax.grid()

# %%
fig, ax = plts.set("APJ")
for idx in range(10):
    ax.plot(x, np.sin(x + idx))
ax.grid()

# %%
fig, ax = plts.set("Presentation")
for idx in range(10):
    ax.plot(x, np.sin(x + idx))
ax.grid()

# %%
import plotsettings as plts
fig, ax = plts.set("Notebook")
for idx in range(10):
    ax.plot(x, np.sin(x + idx))
ax.grid()
ax.set_xlabel(r"Angle [$\theta$]")
ax.set_ylabel(r"$\sin (x)$")
# Out:
# Text(0, 0.5, '$\\sin (x)$')

# %%
import plotsettings as plts
fig, ax = plts.set("Notebook", "twocol")
for idx in range(10):
    ax.plot(x, np.sin(x + idx))
ax.grid()
ax.set_xlabel(r"Angle [$\theta$]")
ax.set_ylabel(r"$\sin (x)$")
# Out:
# Text(0, 0.5, '$\\sin (x)$')

# %%
fig, ax = plts.set("PRD", fig_type="twocol")
for idx in range(10):
    ax.plot(x, np.sin(x + idx))
ax.set_xlabel(r"Angle [$\theta$]")
ax.set_ylabel(r"$\sin (x)$")
ax.grid()
